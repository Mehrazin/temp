# %% [markdown]
# # Notebook 03 — Response Hierarchy and Business Impact

# %%
# CELL 1
# Purpose: imports and config

from nbe_report_functions_final import (
    compute_rank_array,
    compute_top1_agreement,
    compute_response_hierarchy_report,
)

CUSTOMER_ID_COL = "customer_id"
ACTIVE_PRODUCTS = ["product_1", "product_2", "product_3", "product_4", "product_5"]  # replace

# %%
# CELL 2
# Purpose: load priority tables and measurement results

# prism_priority_df = spark.table("your_catalog.your_schema.prism_priority_table_nov")
# legacy_priority_df = spark.table("your_catalog.your_schema.legacy_priority_table_nov")
# measurement_df = spark.table("your_catalog.your_schema.measurement_results_nov")

prism_priority_df = None
legacy_priority_df = None
measurement_df = None

# %%
# CELL 3
# Purpose: create PRISM-vs-Legacy agreement groups and compare outcomes

# prism_rank_df = compute_rank_array(prism_priority_df, ACTIVE_PRODUCTS, customer_id_col=CUSTOMER_ID_COL)
# legacy_rank_df = compute_rank_array(legacy_priority_df, ACTIVE_PRODUCTS, customer_id_col=CUSTOMER_ID_COL)
# top1_df = compute_top1_agreement(prism_rank_df, legacy_rank_df, customer_id_col=CUSTOMER_ID_COL)
# hierarchy_report = compute_response_hierarchy_report(
#     measurement_df=measurement_df,
#     customer_group_df=top1_df.select(CUSTOMER_ID_COL, "top1_same"),
#     customer_id_col=CUSTOMER_ID_COL,
#     group_col_name="top1_same",
#     response_state_col="response_state",
# )
# display(hierarchy_report["response_state_summary"])
# display(hierarchy_report["funnel_summary"])
# display(hierarchy_report["outcome_by_group"])
