# %% [markdown]
# # Notebook 04 — Decile Diagnostics

# %%
# CELL 1
# Purpose: imports and config

from nbe_report_functions_final import compute_decile_diagnostics_report

# Important convention:
# decile 1 = highest
# decile 10 = lowest

# %%
# CELL 2
# Purpose: load scored offer-level dataset

# offered_scores_df = spark.table("your_catalog.your_schema.offered_scores_nov")
# expected columns include at least:
# customer_id, product, prism_score, legacy_score
# optional: prism_decile, legacy_decile

offered_scores_df = None

# %%
# CELL 3
# Purpose: generate decile diagnostics

# decile_report = compute_decile_diagnostics_report(
#     df=offered_scores_df,
#     prism_score_col="prism_score",
#     legacy_score_col="legacy_score",
#     product_col="product",
# )
# display(decile_report["prism_decile_distribution"])
# display(decile_report["legacy_decile_distribution"])
# display(decile_report["decile_transition_matrix"])
