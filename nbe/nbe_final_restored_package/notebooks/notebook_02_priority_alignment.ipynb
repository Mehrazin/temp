# %% [markdown]
# # Notebook 02 — Priority Alignment

# %%
# CELL 1
# Purpose: imports and config

from nbe_report_functions_final import compute_priority_alignment_report

CUSTOMER_ID_COL = "customer_id"
ACTIVE_PRODUCTS = ["product_1", "product_2", "product_3", "product_4", "product_5"]  # replace

# %%
# CELL 2
# Purpose: load November priority table and proposed-offer results

# priority_df = spark.table("your_catalog.your_schema.prism_priority_table_nov")
# proposed_df = spark.table("your_catalog.your_schema.measurement_results_nov").select(CUSTOMER_ID_COL, "proposed_product")

priority_df = None
proposed_df = None

# %%
# CELL 3
# Purpose: generate alignment report

# alignment_report = compute_priority_alignment_report(
#     priority_df=priority_df,
#     proposed_df=proposed_df,
#     active_product_cols=ACTIVE_PRODUCTS,
#     customer_id_col=CUSTOMER_ID_COL,
#     proposed_product_col="proposed_product",
# )
# display(alignment_report["priority_alignment_summary"])
# display(alignment_report["priority_alignment_distribution"])
# display(alignment_report["priority_alignment_df"].limit(20))
