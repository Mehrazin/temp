# %% [markdown]
# # Notebook 05 — Historical Month Comparison

# %%
# CELL 1
# Purpose: imports and config

from nbe_report_functions_final import compute_historical_month_report

# %%
# CELL 2
# Purpose: load May-to-December measurement results

# monthly_df = spark.table("your_catalog.your_schema.measurement_results_may_to_dec")
# expected columns include:
# customer_id, month, product, activated, actioned, interested
# optional: response_state

monthly_df = None

# %%
# CELL 3
# Purpose: month-level and common-customer comparison

# historical_report = compute_historical_month_report(
#     monthly_df=monthly_df,
#     month_col="month",
#     product_col="product",
#     customer_id_col="customer_id",
#     month_a_value="2024-05",
#     month_b_value="2024-11",
# )
# display(historical_report["month_product_rates"])
# display(historical_report["common_month_product_rates"])
